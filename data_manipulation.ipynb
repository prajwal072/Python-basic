# %%
# !pip install pandas

# %%
import pandas as pd
df=pd.read_csv('sales1_data.csv')
df.head()
# Out:
#          Date   Product  Sales Region
# 0  2023-01-01  Product3  738.0   West
# 1  2023-01-02  Product2  868.0  North
# 2  2023-01-03  Product2  554.0   West
# 3  2023-01-04  Product1  618.0  South
# 4  2023-01-05  Product3  501.0   East

# %%
df.isnull().sum()
# Out:
# Date       0
# Product    0
# Sales      6
# Region     0
# dtype: int64

# %%
#handling Missing Values With Mean Imputation
df['Sales'].fillna(df['Sales'].mean())
# Out:
# 0     738.0
# 1     868.0
# 2     554.0
# 3     618.0
# 4     501.0
# 5     554.0
# 6     339.0
# 7     280.0
# 8     806.0
# 9     816.0
# 10    469.0
# 11    554.0
# 12    554.0
# 13    676.0
# 14    183.0
# 15    424.0
# 16    554.0
# 17    554.0
# 18    124.0
# 19    732.0
# 20    554.0
# 21    296.0
# 22    737.0
# 23    531.0
# 24    834.0
# Name: Sales, dtype: float64

# %%
#Renamimhg the Column Names
df.rename(columns={'Sales':'Saless'})
# Out:
#           Date   Product  Saless Region
# 0   2023-01-01  Product3   738.0   West
# 1   2023-01-02  Product2   868.0  North
# 2   2023-01-03  Product2   554.0   West
# 3   2023-01-04  Product1   618.0  South
# 4   2023-01-05  Product3   501.0   East
# 5   2023-01-06  Product1     NaN   West
# 6   2023-01-07  Product3   339.0  South
# 7   2023-01-08  Product3   280.0  South
# 8   2023-01-09  Product2   806.0  North
# 9   2023-01-10  Product2   816.0  South
# 10  2023-01-11  Product3   469.0   West
# 11  2023-01-12  Product3     NaN   East
# 12  2023-01-13  Product3     NaN   East
# 13  2023-01-14  Product3   676.0   East
# 14  2023-01-15  Product1   183.0  South
# 15  2023-01-16  Product1   424.0  South
# 16  2023-01-17  Product1     NaN  South
# 17  2023-01-18  Product1     NaN  South
# 18  2023-01-19  Product2   124.0  North
# 19  2023-01-20  Product3   732.0   West
# 20  2023-01-21  Product2     NaN   West
# 21  2023-01-22  Product3   296.0   West
# ...

# %%
#Data  Grouping And Aggregation
df.groupby('Sales') ['Sales'].mean()
# Out:
# Sales
# 124.0    124.0
# 183.0    183.0
# 280.0    280.0
# 296.0    296.0
# 339.0    339.0
# 424.0    424.0
# 469.0    469.0
# 501.0    501.0
# 531.0    531.0
# 554.0    554.0
# 618.0    618.0
# 676.0    676.0
# 732.0    732.0
# 737.0    737.0
# 738.0    738.0
# 806.0    806.0
# 816.0    816.0
# 834.0    834.0
# 868.0    868.0
# Name: Sales, dtype: float64

# %%
df.groupby(['Region', 'Sales']).agg({'Sales': 'mean', 'Region': 'count'})
# Out:
#               Sales  Region
# Region Sales
# East   501.0  501.0       1
#        531.0  531.0       1
#        676.0  676.0       1
# North  124.0  124.0       1
#        806.0  806.0       1
#        834.0  834.0       1
#        868.0  868.0       1
# South  183.0  183.0       1
#        280.0  280.0       1
#        339.0  339.0       1
#        424.0  424.0       1
#        618.0  618.0       1
#        816.0  816.0       1
# West   296.0  296.0       1
#        469.0  469.0       1
#        554.0  554.0       1
#        732.0  732.0       1
#        737.0  737.0       1
#        738.0  738.0       1

# %%
# !pip install lxml
# !pip install html5lib

# %%
# !pip install openpyxl

# %%
import pandas as pd
from io import StringIO

data = '[{"Name": "John", "Age": "30", "City": "New York"}]'

df = pd.read_json(StringIO(data))

print(df.head())
# Out:
#    Name  Age      City
# 0  John   30  New York

# %%
df=pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data",header=None)
df.head()
df.to_csv('wine.csv',index=False)

# %%
#url="https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/"
#df=pd.read_html(url)
df=pd.read_excel("wine.xlsx")
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 3
#       1 #url="https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/"
#       2 #df=pd.read_html(url)
# ----> 3 df=pd.read_excel("wine.xlsx")
#       4 df.head()
#
# File c:\Users\prajw\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
# ...
