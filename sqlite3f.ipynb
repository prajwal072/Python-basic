# %% [markdown]
# <a href="https://colab.research.google.com/github/prajwal072/Python-basic/blob/main/sqlite3f.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3
connection=sqlite3.connect('Example.db')
connection
cursor=connection.cursor()#Establish a connection
#Table Creation
cursor.execute('''
Create Table People(
    id integer  primary key,
    name text not null,
    age int not null
)
''')
connection.commit()#Used to commit the changes

# %%
#insert the data
cursor.execute('''
insert into People(name,age)
values("Prajwal",22)
''')
connection.commit()

# %%
#fetch the data
cursor.execute('''
select * from People

''')
rows=cursor.fetchall()
for row in rows:
    print(row)
# Out:
# (1, 'Prajwal', 22)

# %%
#update
cursor.execute('''
update People
set age=45
where name="Prajwal"
''')
connection.commit()

# %%
cursor.execute('''
select * from People

''')
rows=cursor.fetchall()
for row in rows:
    print(row)
# Out:
# (1, 'Prajwal', 45)

# %%
#Delete
cursor.execute('''
delete from People
where name="Prajwal"
''')
connection.commit()
